# %%
import pandas as pd
dic = pd.read_excel('surveydata1.xlsx')

# %%
dic.head(3).T
# Out:
#                                                                                    0  \
# Timestamp                                                        20/06/2020 00:45:49
# Gender                                                                        Female
# academic year                                                             First year
# GPA                                                                       2.5 - 2.99
# Field                                         Engineering and Information Technology
# assignments and Exam                                                           Agree
# teatcher experiences                                                           Agree
# communication                                                                    yes
# contine of e-Learning                                                            Yes
# note                                                                             NaN
# ...

# %%
dic.shape
# Out:
# (115, 15)

# %%
dic.isnull().sum()
# Out:
# Timestamp                                         0
# Gender                                            0
# academic year                                     0
# GPA                                               0
# Field                                             0
# assignments and Exam                              0
# teatcher experiences                              0
# communication                                     0
# contine of e-Learning                             0
# note                                            115
# working with tools and metarial in eLearning      0
# cause stress                                      0
#  technical problems                               0
# satisfied with the speed of your internet         0
# materials suitable for online                     0
# dtype: int64

# %%
dic.drop(['note','Timestamp'],axis =1,inplace=True)

# %%
dic.head(1).T
# Out:
#                                                                                    0
# Gender                                                                        Female
# academic year                                                             First year
# GPA                                                                       2.5 - 2.99
# Field                                         Engineering and Information Technology
# assignments and Exam                                                           Agree
# teatcher experiences                                                           Agree
# communication                                                                    yes
# contine of e-Learning                                                            Yes
# working with tools and metarial in eLearning                                disagree
# cause stress                                                                   Agree
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
dic.head(2).T
# Out:
#                                                                                    0  \
# Gender                                                                        Female
# academic year                                                             First year
# GPA                                                                       2.5 - 2.99
# Field                                         Engineering and Information Technology
# assignments and Exam                                                           Agree
# teatcher experiences                                                           Agree
# communication                                                                    yes
# contine of e-Learning                                                            Yes
# working with tools and metarial in eLearning                                disagree
# cause stress                                                                   Agree
# ...

# %%
df_mar = pd.crosstab(dic['Gender'], dic['assignments and Exam'])
print(df_mar)

df_mar.plot.bar()
# Out:
# assignments and Exam  Agree  Disagree
# Gender
# Female                   37        33
# Male                     22        23

# %%
df_mar = pd.crosstab(dic['Gender'], dic['materials suitable for online'])
print(df_mar)

df_mar.plot.bar()
# Out:
# materials suitable for online  Agree  Disagree
# Gender
# Female                            35        35
# Male                              24        21

# %%
df_mar = pd.crosstab(dic['Gender'], dic['cause stress'])
print(df_mar)

df_mar.plot.bar()
# Out:
# cause stress  Agree  Disagree
# Gender
# Female           46        24
# Male             20        25

# %%
df_mar = pd.crosstab(dic['Gender'], dic['working with tools and metarial in eLearning'])
print(df_mar)

df_mar.plot.bar()
# Out:
# working with tools and metarial in eLearning  agree  disagree
# Gender
# Female                                           37        33
# Male                                             17        28

# %%
df_mar = pd.crosstab(dic['Gender'], dic['teatcher experiences'])
print(df_mar)

df_mar.plot.bar()
# Out:
# teatcher experiences  Agree  Disagree
# Gender
# Female                   39        31
# Male                     23        22

# %%
df_mar = pd.crosstab(dic['Gender'], dic['communication'])
print(df_mar)

df_mar.plot.bar()
# Out:
# communication  I didn't try to contact him  No  yes
# Gender
# Female                                  16  18   36
# Male                                     8  18   19

# %%
dic.head().T
# Out:
#                                                                                    0  \
# Gender                                                                        Female
# academic year                                                             First year
# GPA                                                                       2.5 - 2.99
# Field                                         Engineering and Information Technology
# assignments and Exam                                                           Agree
# teatcher experiences                                                           Agree
# communication                                                                    yes
# contine of e-Learning                                                            Yes
# working with tools and metarial in eLearning                                disagree
# cause stress                                                                   Agree
# ...

# %%
df_mar = pd.crosstab(dic['academic year'], dic['assignments and Exam'])
print(df_mar)

df_mar.plot.bar()
# Out:
# assignments and Exam   Agree  Disagree
# academic year
# First year                16        17
# Fourth and Fifth year     13        17
# Second year               18        11
# Third year                12        11

# %%
df_mar = pd.crosstab(dic['academic year'], dic['materials suitable for online'])
print(df_mar)

df_mar.plot.bar()
# Out:
# materials suitable for online  Agree  Disagree
# academic year
# First year                        14        19
# Fourth and Fifth year             15        15
# Second year                       19        10
# Third year                        11        12

# %%
df_mar = pd.crosstab(dic['academic year'], dic['working with tools and metarial in eLearning'])
print(df_mar)

df_mar.plot.bar()
# Out:
# working with tools and metarial in eLearning  agree  disagree
# academic year
# First year                                       18        15
# Fourth and Fifth year                             7        23
# Second year                                      19        10
# Third year                                       10        13

# %%
df_mar = pd.crosstab(dic['academic year'], dic['satisfied with the speed of your internet'])
print(df_mar)

df_mar.plot.bar()
# Out:
# satisfied with the speed of your internet  Agree  Disagree
# academic year
# First year                                    13        20
# Fourth and Fifth year                         11        19
# Second year                                   16        13
# Third year                                     8        15

# %%
df_mar = pd.crosstab(dic['academic year'], dic['cause stress'])
print(df_mar)

df_mar.plot.bar()
# Out:
# cause stress           Agree  Disagree
# academic year
# First year                19        14
# Fourth and Fifth year     11        19
# Second year               23         6
# Third year                13        10

# %%
df_mar = pd.crosstab(dic['academic year'], dic['cause stress'])
print(df_mar)

df_mar.plot.bar()
# Out:
# cause stress           Agree  Disagree
# academic year
# First year                19        14
# Fourth and Fifth year     11        19
# Second year               23         6
# Third year                13        10

# %%
df_mar = pd.crosstab(dic['academic year'], dic['Gender'])
print(df_mar)

df_mar.plot.bar()
# Out:
# Gender                 Female  Male
# academic year
# First year                 23    10
# Fourth and Fifth year      20    10
# Second year                15    14
# Third year                 12    11

# %%
df_mar = pd.crosstab(dic['academic year'], dic['teatcher experiences'])
print(df_mar)

df_mar.plot.bar()
# Out:
# teatcher experiences   Agree  Disagree
# academic year
# First year                18        15
# Fourth and Fifth year     15        15
# Second year               17        12
# Third year                12        11

# %%
df_mar = pd.crosstab(dic['academic year'], dic['communication'])
print(df_mar)

df_mar.plot.bar()
# Out:
# communication          I didn't try to contact him  No  yes
# academic year
# First year                                       5  12   16
# Fourth and Fifth year                           10   8   12
# Second year                                      5  10   14
# Third year                                       4   6   13

# %%
dic.head(2).T
# Out:
#                                                                                    0  \
# Gender                                                                        Female
# academic year                                                             First year
# GPA                                                                       2.5 - 2.99
# Field                                         Engineering and Information Technology
# assignments and Exam                                                           Agree
# teatcher experiences                                                           Agree
# communication                                                                    yes
# contine of e-Learning                                                            Yes
# working with tools and metarial in eLearning                                disagree
# cause stress                                                                   Agree
# ...

# %%
df_mar = pd.crosstab(dic['GPA'], dic['communication'])
print(df_mar)

df_mar.plot.bar()
# Out:
# communication   I didn't try to contact him  No  yes
# GPA
# 1.67 -1.99                                5   8    5
# 2.00 - 2.49                               4   8   14
# 2.5 - 2.99                                2   7   15
# 3.00 - 4.00                               6   8   16
# Less than 1.67                            7   5    5

# %%
df_mar = pd.crosstab(dic['GPA'], dic['Gender'])
print(df_mar)

df_mar.plot.bar()
# Out:
# Gender          Female  Male
# GPA
# 1.67 -1.99           9     9
# 2.00 - 2.49         17     9
# 2.5 - 2.99          13    11
# 3.00 - 4.00         23     7
# Less than 1.67       8     9

# %%
df_mar = pd.crosstab(dic['GPA'], dic['assignments and Exam'])
print(df_mar)

df_mar.plot.bar()
# Out:
# assignments and Exam  Agree  Disagree
# GPA
# 1.67 -1.99                5        13
# 2.00 - 2.49              17         9
# 2.5 - 2.99               15         9
# 3.00 - 4.00              18        12
# Less than 1.67            4        13

# %%
df_mar = pd.crosstab(dic['GPA'], dic['materials suitable for online'])
print(df_mar)

df_mar.plot.bar()
# Out:
# materials suitable for online  Agree  Disagree
# GPA
# 1.67 -1.99                         7        11
# 2.00 - 2.49                       19         7
# 2.5 - 2.99                        14        10
# 3.00 - 4.00                       15        15
# Less than 1.67                     4        13

# %%
df_mar = pd.crosstab(dic['GPA'], dic['teatcher experiences'])
print(df_mar)

df_mar.plot.bar()
# Out:
# teatcher experiences  Agree  Disagree
# GPA
# 1.67 -1.99                5        13
# 2.00 - 2.49              17         9
# 2.5 - 2.99               17         7
# 3.00 - 4.00              20        10
# Less than 1.67            3        14

# %%
df_mar = pd.crosstab(dic['GPA'], dic['working with tools and metarial in eLearning'])
print(df_mar)

df_mar.plot.bar()
# Out:
# working with tools and metarial in eLearning  agree  disagree
# GPA
# 1.67 -1.99                                        7        11
# 2.00 - 2.49                                      14        12
# 2.5 - 2.99                                       10        14
# 3.00 - 4.00                                      18        12
# Less than 1.67                                    5        12

# %%
df_mar = pd.crosstab(dic['GPA'], dic['cause stress'])
print(df_mar)

df_mar.plot.bar()
# Out:
# cause stress    Agree  Disagree
# GPA
# 1.67 -1.99          8        10
# 2.00 - 2.49        17         9
# 2.5 - 2.99         15         9
# 3.00 - 4.00        21         9
# Less than 1.67      5        12

# %%
df_mar = pd.crosstab(dic['GPA'], dic['satisfied with the speed of your internet'])
print(df_mar)

df_mar.plot.bar()
# Out:
# satisfied with the speed of your internet  Agree  Disagree
# GPA
# 1.67 -1.99                                     5        13
# 2.00 - 2.49                                   13        13
# 2.5 - 2.99                                    15         9
# 3.00 - 4.00                                   12        18
# Less than 1.67                                 3        14

# %%
dic.head(2).T
# Out:
#                                                                                    0  \
# Gender                                                                        Female
# academic year                                                             First year
# GPA                                                                       2.5 - 2.99
# Field                                         Engineering and Information Technology
# assignments and Exam                                                           Agree
# teatcher experiences                                                           Agree
# communication                                                                    yes
# contine of e-Learning                                                            Yes
# working with tools and metarial in eLearning                                disagree
# cause stress                                                                   Agree
# ...

# %%
df_mar = pd.crosstab(dic['Field'], dic['satisfied with the speed of your internet'])
print(df_mar)

df_mar.plot.bar()
# Out:
# satisfied with the speed of your internet  Agree  Disagree
# Field
# Administrative and Financial Science           6         6
# Allied Medical Science                         5         3
# Art                                            4         5
# Dentistry                                      1         8
# Engineering and Information Technology        16        11
# Law                                            2         6
# Nursing                                        2         6
# Sciences                                       9        15
# Sport Science                                  3         7

# %%
df_mar = pd.crosstab(dic['Field'], dic['assignments and Exam'])
print(df_mar)

df_mar.plot.bar()
# Out:
# assignments and Exam                    Agree  Disagree
# Field
# Administrative and Financial Science        7         5
# Allied Medical Science                      5         3
# Art                                         7         2
# Dentistry                                   3         6
# Engineering and Information Technology     18         9
# Law                                         4         4
# Nursing                                     5         3
# Sciences                                    8        16
# Sport Science                               2         8

# %%
df_mar = pd.crosstab(dic['Field'], dic['materials suitable for online'])
print(df_mar)

df_mar.plot.bar()
# Out:
# materials suitable for online           Agree  Disagree
# Field
# Administrative and Financial Science        5         7
# Allied Medical Science                      5         3
# Art                                         8         1
# Dentistry                                   2         7
# Engineering and Information Technology     18         9
# Law                                         5         3
# Nursing                                     5         3
# Sciences                                    8        16
# Sport Science                               3         7

# %%
df_mar = pd.crosstab(dic['Field'], dic['teatcher experiences'])
print(df_mar)

df_mar.plot.bar()
# Out:
# teatcher experiences                    Agree  Disagree
# Field
# Administrative and Financial Science        6         6
# Allied Medical Science                      5         3
# Art                                         7         2
# Dentistry                                   2         7
# Engineering and Information Technology     21         6
# Law                                         3         5
# Nursing                                     6         2
# Sciences                                   10        14
# Sport Science                               2         8

# %%
df_mar = pd.crosstab(dic['Field'], dic['communication'])
print(df_mar)

df_mar.plot.bar()
# Out:
# communication                           I didn't try to contact him  No  yes
# Field
# Administrative and Financial Science                              2   5    5
# Allied Medical Science                                            1   2    5
# Art                                                               2   1    6
# Dentistry                                                         3   3    3
# Engineering and Information Technology                            4   8   15
# Law                                                               2   1    5
# Nursing                                                           2   2    4
# Sciences                                                          5  10    9
# Sport Science                                                     3   4    3

# %%
conda install nbconvert
# Out:
# ...
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\itaha\anaconda3
#
#   added / updated specs:
#     - nbconvert
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     conda-4.8.3                |           py37_0         2.8 MB
#     ------------------------------------------------------------
#                                            Total:         2.8 MB
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   conda              conda-forge::conda-4.8.3-py37hc8dfbb8~ --> pkgs/main::conda-4.8.3-py37_0
#
#
#
# ...
#
# conda-4.8.3          | 2.8 MB    |            |   0%
# conda-4.8.3          | 2.8 MB    |            |   1%
# conda-4.8.3          | 2.8 MB    | 2          |   2%
# conda-4.8.3          | 2.8 MB    | 8          |   8%
# conda-4.8.3          | 2.8 MB    | #5         |  15%
# ...

# %%
sudo apt-get install pandoc
# Out:
#   File "<ipython-input-13-14a39327921c>", line 1
#     sudo apt-get install pandoc
#            ^
# SyntaxError: invalid syntax
